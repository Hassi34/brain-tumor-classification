# %% [markdown]
# ## Brain Tumor classification
#
# ### Imports

# %%
import numpy as np  
import matplotlib.pyplot as plt 
import os                  
from PIL import Image
import pandas as pd 

import tensorflow as tf
import keras 
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense, Activation, Dropout, BatchNormalization  
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2L
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras import Model, layers
from tensorflow.keras.models import load_model

#from inference import Inference
from aipilot.tf.cv import DataPrep , GradCam
from aipilot.tf import Devices, callbacks, Evaluator
import cv2

# %%
devices = Devices()

# %%
devices.gpu_device
# Out:
# [INFO] Tensorflow is built with cuda support ✅
# [INFO] [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [INFO] {'device_name': 'NVIDIA GeForce RTX 3050 Ti Laptop GPU', 'compute_capability': (8, 6)}

# %% [markdown]
# ## Project Directories

# %%
BASE_DIR = os.path.relpath(os.getcwd())
DATA_DIR = os.path.join(BASE_DIR, "dataset", "preprocessed", "Training")

ARTIFACTS_DIR = os.path.join(BASE_DIR, 'artifacts')
os.makedirs(ARTIFACTS_DIR, exist_ok=True)

CKPT_DIR = os.path.join(ARTIFACTS_DIR, "ckpt")
os.makedirs(CKPT_DIR, exist_ok=True)

MODELS_DIR = os.path.join(ARTIFACTS_DIR, "models")
os.makedirs(MODELS_DIR, exist_ok=True)

LOGS_DIR = os.path.join(BASE_DIR, "logs")
os.makedirs(LOGS_DIR, exist_ok=True)

CKPT_FILE_NAME = os.path.join(CKPT_DIR, ".mdl_wts.hdf5")
MODEL_NAME = os.path.join(MODELS_DIR, "model.h5")

# %% [markdown]
# ## Data Preprocessing

# %%
data_ops = DataPrep(DATA_DIR)
custom_data_augmentation = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=10,                        
        width_shift_range=0.05,
        rescale=1./255,
        height_shift_range=0.05,
        horizontal_flip=True)
train_generator, valid_generator = data_ops.data_generators( val_split=0.2, batch_size=16,
                                                            data_augmentation= True,
                                                            augmentation_strategy= custom_data_augmentation)
steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size
img = data_ops.sample_images(train_generator)
# Out:
# Found 400 images belonging to 4 classes.
# Found 80 images belonging to 4 classes.

# %%
data_ops.classwise_img_count(train_generator)
# Out:
# {'glioma': 1321, 'meningioma': 1339, 'notumor': 1595, 'pituitary': 1457}

# %%
data_ops.classwise_img_count(valid_generator)
# Out:
# {'glioma': 264, 'meningioma': 267, 'notumor': 319, 'pituitary': 291}

# %% [markdown]
# ## Model Training

# %%
(early_stopping_cb, checkpointing_cb,
 tensorboard_cb, reduce_on_plateau_cb) = callbacks(
                                                   CKPT_FILE_NAME,LOGS_DIR, es_patience=10, lr_patience=3
                                                    )

# %%
## ResNet50
conv_base = DenseNet121(
        include_top=False,
        weights='imagenet',
        input_shape = (224, 224, 3)
)
for layer in conv_base.layers[:-5]:
    layer.trainable = False

# %%
x = conv_base.output    
x = GlobalAveragePooling2D()(x)
x = Dense(units=512)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(rate=0.3)(x)
x = Dense(units=128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(rate=0.2)(x)
x = Dense(units=64)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dense(units=32, activation='relu')(x)
predictions = layers.Dense(4, activation='softmax')(x)
model = Model(conv_base.input, outputs = predictions)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
history = []

# %%
h = model.fit(
    train_generator,
    validation_data = valid_generator,
    epochs=50,
    steps_per_epoch=steps_per_epoch, 
    validation_steps=validation_steps,
    callbacks = [tensorboard_cb , early_stopping_cb, checkpointing_cb, reduce_on_plateau_cb]
    )
history.append(h)
# Out:
# Epoch 1/50
# 357/357 [==============================] - 57s 144ms/step - loss: 0.5003 - accuracy: 0.8130 - val_loss: 0.3367 - val_accuracy: 0.8688 - lr: 0.0010
# Epoch 2/50
# 357/357 [==============================] - 52s 146ms/step - loss: 0.3209 - accuracy: 0.8813 - val_loss: 0.2007 - val_accuracy: 0.9269 - lr: 0.0010
# Epoch 3/50
# 357/357 [==============================] - 55s 154ms/step - loss: 0.2875 - accuracy: 0.8902 - val_loss: 0.1709 - val_accuracy: 0.9349 - lr: 0.0010
# Epoch 4/50
# 357/357 [==============================] - 55s 154ms/step - loss: 0.2462 - accuracy: 0.9077 - val_loss: 0.1522 - val_accuracy: 0.9445 - lr: 0.0010
# Epoch 5/50
# 357/357 [==============================] - 54s 150ms/step - loss: 0.2441 - accuracy: 0.9128 - val_loss: 0.1626 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 6/50
# 357/357 [==============================] - 55s 153ms/step - loss: 0.1977 - accuracy: 0.9279 - val_loss: 0.1257 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 7/50
# 357/357 [==============================] - 58s 161ms/step - loss: 0.1922 - accuracy: 0.9321 - val_loss: 0.0891 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 8/50
# 357/357 [==============================] - 62s 172ms/step - loss: 0.1738 - accuracy: 0.9389 - val_loss: 0.0774 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 9/50
# 357/357 [==============================] - 62s 174ms/step - loss: 0.1586 - accuracy: 0.9431 - val_loss: 0.0539 - val_accuracy: 0.9824 - lr: 0.0010
# Epoch 10/50
# 357/357 [==============================] - 58s 161ms/step - loss: 0.1570 - accuracy: 0.9435 - val_loss: 0.0639 - val_accuracy: 0.9736 - lr: 0.0010
# Epoch 11/50
# 357/357 [==============================] - 58s 161ms/step - loss: 0.1554 - accuracy: 0.9468 - val_loss: 0.0845 - val_accuracy: 0.9613 - lr: 0.0010
# Epoch 12/50
# 357/357 [==============================] - 56s 157ms/step - loss: 0.1360 - accuracy: 0.9505 - val_loss: 0.0615 - val_accuracy: 0.9789 - lr: 0.0010
# Epoch 13/50
# 357/357 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9566
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 357/357 [==============================] - 56s 158ms/step - loss: 0.1124 - accuracy: 0.9566 - val_loss: 0.1002 - val_accuracy: 0.9577 - lr: 0.0010
# Epoch 14/50
# 357/357 [==============================] - 57s 159ms/step - loss: 0.1016 - accuracy: 0.9638 - val_loss: 0.0301 - val_accuracy: 0.9886 - lr: 2.0000e-04
# Epoch 15/50
# 357/357 [==============================] - 57s 158ms/step - loss: 0.0850 - accuracy: 0.9699 - val_loss: 0.0269 - val_accuracy: 0.9894 - lr: 2.0000e-04
# Epoch 16/50
# 357/357 [==============================] - 55s 155ms/step - loss: 0.0858 - accuracy: 0.9687 - val_loss: 0.0321 - val_accuracy: 0.9859 - lr: 2.0000e-04
# Epoch 17/50
# 357/357 [==============================] - 56s 158ms/step - loss: 0.0767 - accuracy: 0.9715 - val_loss: 0.0183 - val_accuracy: 0.9956 - lr: 2.0000e-04
# Epoch 18/50
# 357/357 [==============================] - 56s 156ms/step - loss: 0.0698 - accuracy: 0.9753 - val_loss: 0.0159 - val_accuracy: 0.9956 - lr: 2.0000e-04
# Epoch 19/50
# 357/357 [==============================] - 55s 153ms/step - loss: 0.0657 - accuracy: 0.9795 - val_loss: 0.0192 - val_accuracy: 0.9930 - lr: 2.0000e-04
# Epoch 20/50
# 357/357 [==============================] - 55s 153ms/step - loss: 0.0647 - accuracy: 0.9771 - val_loss: 0.0165 - val_accuracy: 0.9947 - lr: 2.0000e-04
# Epoch 21/50
# 357/357 [==============================] - 58s 162ms/step - loss: 0.0558 - accuracy: 0.9809 - val_loss: 0.0104 - val_accuracy: 0.9974 - lr: 2.0000e-04
# Epoch 22/50
# 357/357 [==============================] - 55s 153ms/step - loss: 0.0591 - accuracy: 0.9793 - val_loss: 0.0167 - val_accuracy: 0.9938 - lr: 2.0000e-04
# Epoch 23/50
# 357/357 [==============================] - 55s 154ms/step - loss: 0.0595 - accuracy: 0.9792 - val_loss: 0.0094 - val_accuracy: 0.9982 - lr: 2.0000e-04
# Epoch 24/50
# 357/357 [==============================] - 54s 152ms/step - loss: 0.0602 - accuracy: 0.9797 - val_loss: 0.0129 - val_accuracy: 0.9965 - lr: 2.0000e-04
# Epoch 25/50
# 357/357 [==============================] - 56s 157ms/step - loss: 0.0563 - accuracy: 0.9792 - val_loss: 0.0082 - val_accuracy: 0.9991 - lr: 2.0000e-04
# Epoch 26/50
# 357/357 [==============================] - 55s 154ms/step - loss: 0.0504 - accuracy: 0.9832 - val_loss: 0.0095 - val_accuracy: 0.9974 - lr: 2.0000e-04
# Epoch 27/50
# 357/357 [==============================] - 55s 155ms/step - loss: 0.0580 - accuracy: 0.9804 - val_loss: 0.0084 - val_accuracy: 0.9991 - lr: 2.0000e-04
# Epoch 28/50
# 357/357 [==============================] - 56s 157ms/step - loss: 0.0461 - accuracy: 0.9827 - val_loss: 0.0091 - val_accuracy: 0.9974 - lr: 2.0000e-04
# Epoch 29/50
# 357/357 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9830
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 357/357 [==============================] - 57s 160ms/step - loss: 0.0506 - accuracy: 0.9830 - val_loss: 0.0100 - val_accuracy: 0.9982 - lr: 2.0000e-04
# Epoch 30/50
# 357/357 [==============================] - 60s 168ms/step - loss: 0.0435 - accuracy: 0.9839 - val_loss: 0.0079 - val_accuracy: 0.9974 - lr: 4.0000e-05
# Epoch 31/50
# 357/357 [==============================] - 59s 165ms/step - loss: 0.0456 - accuracy: 0.9841 - val_loss: 0.0057 - val_accuracy: 0.9982 - lr: 4.0000e-05
# Epoch 32/50
# 357/357 [==============================] - 59s 165ms/step - loss: 0.0461 - accuracy: 0.9844 - val_loss: 0.0049 - val_accuracy: 1.0000 - lr: 4.0000e-05
# Epoch 33/50
# 357/357 [==============================] - 59s 166ms/step - loss: 0.0383 - accuracy: 0.9867 - val_loss: 0.0049 - val_accuracy: 1.0000 - lr: 4.0000e-05
# Epoch 34/50
# 357/357 [==============================] - 61s 171ms/step - loss: 0.0451 - accuracy: 0.9841 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 4.0000e-05
# Epoch 35/50
# 357/357 [==============================] - 61s 171ms/step - loss: 0.0377 - accuracy: 0.9886 - val_loss: 0.0046 - val_accuracy: 0.9991 - lr: 4.0000e-05
# Epoch 36/50
# 357/357 [==============================] - 62s 174ms/step - loss: 0.0413 - accuracy: 0.9841 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 4.0000e-05
# Epoch 37/50
# 357/357 [==============================] - 63s 176ms/step - loss: 0.0351 - accuracy: 0.9870 - val_loss: 0.0045 - val_accuracy: 0.9991 - lr: 4.0000e-05
# Epoch 38/50
# 357/357 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9856
# Epoch 38: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 357/357 [==============================] - 58s 161ms/step - loss: 0.0407 - accuracy: 0.9856 - val_loss: 0.0051 - val_accuracy: 0.9982 - lr: 4.0000e-05
# Epoch 39/50
# 357/357 [==============================] - 69s 192ms/step - loss: 0.0369 - accuracy: 0.9883 - val_loss: 0.0049 - val_accuracy: 0.9991 - lr: 8.0000e-06
# Epoch 40/50
# 357/357 [==============================] - 66s 186ms/step - loss: 0.0408 - accuracy: 0.9876 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 41/50
# 357/357 [==============================] - 67s 187ms/step - loss: 0.0358 - accuracy: 0.9870 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 42/50
# 357/357 [==============================] - 69s 194ms/step - loss: 0.0356 - accuracy: 0.9877 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 43/50
# 357/357 [==============================] - 66s 185ms/step - loss: 0.0353 - accuracy: 0.9881 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 44/50
# 357/357 [==============================] - 71s 199ms/step - loss: 0.0352 - accuracy: 0.9893 - val_loss: 0.0043 - val_accuracy: 0.9991 - lr: 8.0000e-06
# Epoch 45/50
# 357/357 [==============================] - 67s 187ms/step - loss: 0.0392 - accuracy: 0.9879 - val_loss: 0.0041 - val_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 46/50
# 357/357 [==============================] - 62s 175ms/step - loss: 0.0383 - accuracy: 0.9877 - val_loss: 0.0043 - val_accuracy: 0.9991 - lr: 8.0000e-06
# Epoch 47/50
# 357/357 [==============================] - 61s 170ms/step - loss: 0.0332 - accuracy: 0.9884 - val_loss: 0.0042 - val_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 48/50
# 357/357 [==============================] - 60s 167ms/step - loss: 0.0364 - accuracy: 0.9872 - val_loss: 0.0043 - val_accuracy: 1.0000 - lr: 8.0000e-06
# Epoch 49/50
# 357/357 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9891
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 357/357 [==============================] - 58s 161ms/step - loss: 0.0356 - accuracy: 0.9891 - val_loss: 0.0043 - val_accuracy: 0.9991 - lr: 8.0000e-06
# Epoch 50/50
# 357/357 [==============================] - 58s 163ms/step - loss: 0.0367 - accuracy: 0.9872 - val_loss: 0.0045 - val_accuracy: 0.9991 - lr: 1.6000e-06

# %%
saved_ckpt = os.path.join( CKPT_FILE_NAME)
loaded_ckpt = keras.models.load_model(saved_ckpt)

# %%
#starting the training again from the last checkpoint
h = loaded_ckpt.fit(
    train_generator,
    validation_data = valid_generator,
    epochs=50,
    steps_per_epoch=steps_per_epoch, 
    validation_steps=validation_steps,
    callbacks = [tensorboard_cb , early_stopping_cb, checkpointing_cb, reduce_on_plateau_cb]
    )
history.append(h)

# %%
history_df = pd.DataFrame()
for h in history:
    history_df = pd.concat([history_df, pd.DataFrame.from_records(h.history)])

# %%
history_df.reset_index(drop=True).plot(figsize= (8,5));

# %% [markdown]
# ## Saving and Loading Model

# %%
model = load_model(CKPT_FILE_NAME)
model.save(MODEL_NAME)

# %%
model = load_model(MODEL_NAME)

# %% [markdown]
# ## Model Evaluation

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
#Get the last conv layer name
for layer in model.layers[-20:]:
    print(layer.name)
# Out:
# conv5_block16_1_bn
# conv5_block16_1_relu
# conv5_block16_2_conv
# conv5_block16_concat
# bn
# relu
# global_average_pooling2d_3
# dense_7
# batch_normalization_3
# activation_3
# dropout_4
# dense_8
# batch_normalization_4
# activation_4
# dropout_5
# dense_9
# batch_normalization_5
# activation_5
# dense_10
# dense_11

# %%
os.makedirs("inference_images", exist_ok= True)
input_img_path = os.path.join("inference_images", "input.jpg")
preprocessed_img_path = os.path.join("inference_images", "preprocessed.png")
output_img_path = os.path.join("inference_images", "output_img.png")

# %%
from preprocess import prep_img
img = cv2.imread("./dataset/Testing/meningioma/Te-meTr_0002.jpg")
preprocessed_img = prep_img(img, IMG_SIZE=224)
cv2.imwrite(preprocessed_img_path, preprocessed_img)
gradcam = GradCam(model, "conv5_block16_concat",
                  in_img_path = preprocessed_img_path,
                  out_img_path = output_img_path,
                  normalize_img=True)
gradcam_img = gradcam.get_gradcam()

# %%
train_generator.class_indices
# Out:
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
# Prediction through GradCam
gradcam.preds.numpy()
# Out:
# array([[1.7845858e-05, 9.9665016e-01, 3.3289855e-03, 3.0692538e-06]],
#       dtype=float32)

# %%
# checking the accuracy 
result = model.evaluate(valid_generator)
print('\n', 'Validation Loss:', round(result[0], 3))
print('\n', 'Validation Accuracy:', round(result[1], 3))
# Out:
# 72/72 [==============================] - 7s 69ms/step - loss: 0.0040 - accuracy: 1.0000
#
#  Validation Loss: 0.004
#
#  Validation Accuracy: 1.0

# %%
eval= Evaluator(model, train_generator, valid_generator)
# Out:
# 72/72 [==============================] - 6s 68ms/step

# %%
eval.confusion_matrix()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\hasna\\miniconda3\\envs\\brain-tumour\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
eval.classification_report()
# Out:
#               precision    recall  f1-score   support
#
#       glioma       1.00      1.00      1.00       264
#   meningioma       1.00      1.00      1.00       267
#      notumor       1.00      1.00      1.00       319
#    pituitary       1.00      1.00      1.00       291
#
#     accuracy                           1.00      1141
#    macro avg       1.00      1.00      1.00      1141
# weighted avg       1.00      1.00      1.00      1141

# %%
print(train_generator.class_indices)
images, labels = valid_generator.next()
predictions = model.predict(np.expand_dims(images[0], axis=0))
np.argmax(predictions[0])
# Out:
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}
# 1/1 [==============================] - 1s 1s/step
# 0

# %%
_, valid_generator_with_shuffle  = data_ops.data_generators( val_split=0.2,val_shuffle=True, batch_size=16, data_augmentation= False)
#_, valid_generator_with_shuffle = data_ops.data_generators(train_dir=DATA_DIR, val_shuffle=True, val_dir=TEST_DIR, batch_size=16)
#plot a random sample of test images, their predicted labels, and ground truth
classes = list(train_generator.class_indices.keys())
plt.figure(figsize=(10, 10))
images, labels = valid_generator_with_shuffle.next()
labels = np.argmax(labels, axis=1)
for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    prediction = classes[np.argmax(model.predict(np.expand_dims(images[i], axis=0))[0], axis=0)]
    plt.imshow(images[i])
    plt.title(f"{classes[labels[i]]} ({prediction})")
    plt.axis("off")
# Out:
# Found 4571 images belonging to 4 classes.
# Found 1141 images belonging to 4 classes.
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
## Making prediction
#img_arr = np.asarray(Image.open("./dataset/normal/NORMAL2-IM-0489-0001.jpeg"))
img = cv2.imread("./dataset/Testing/meningioma/Te-me_0056.jpg")
img_arr = prep_img(img, IMG_SIZE=224)
img_arr =  np.expand_dims(img_arr, axis=0)/255.0
prediction = np.round(model.predict(img_arr), decimals = 6)
prediction
# Out:
# 1/1 [==============================] - 0s 39ms/step
# array([[9.14000e-04, 9.89926e-01, 9.16000e-03, 1.00000e-06]],
#       dtype=float32)

# %%
prediction = model.predict(img_arr)
pred_cls_label = np.argmax(prediction, axis=1)[0]
pred_cls_label
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1

# %%
train_generator.class_indices
# Out:
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
np.set_printoptions(suppress=True)
print(f"Probability of being Glioma is {round(prediction[0][0]*100, 5)} %")
print(f"Probability of being Meningioma is {round(prediction[0][1]*100, 5)} %")
print(f"Probability of being No tumor is {round(prediction[0][2]*100, 5)} %")
print(f"Probability of being Pituitary is {round(prediction[0][3]*100, 5)} %")
# Out:
# Probability of being Glioma is 0.09138 %
# Probability of being Meningioma is 98.99256 %
# Probability of being No tumor is 0.91599 %
# Probability of being Pituitary is 6e-05 %

# %%
pred_cls = eval.class_names[pred_cls_label]
pred_cls
# Out:
# 'meningioma'

# %% [markdown]
# ## Testing on Test Data

# %% [markdown]
# ### Getting Data Loader

# %%
BASE_DIR = os.path.relpath(os.getcwd())
DATA_DIR = os.path.join(BASE_DIR, "dataset", "preprocessed", "Testing")

data_ops = DataPrep(DATA_DIR)
test_generator, _ = data_ops.data_generators( val_split=0.0, batch_size=32, train_shuffle= False,
                                              val_shuffle= False, data_augmentation= False)
img = data_ops.sample_images(test_generator)
# Out:
# Found 400 images belonging to 4 classes.
# Found 0 images belonging to 4 classes.

# %%
# checking the accuracy 
result = model.evaluate(test_generator)
print('\n', 'Test Loss:', round(result[0], 3))
print('\n', 'Test Accuracy:', round(result[1], 3))
# Out:
# 13/13 [==============================] - 2s 118ms/step - loss: 0.0168 - accuracy: 0.9950
#
#  Test Loss: 0.017
#
#  Test Accuracy: 0.995

# %%
eval= Evaluator(model, train_generator, test_generator)
# Out:
# 13/13 [==============================] - 2s 137ms/step

# %%
eval.confusion_matrix();

# %%
eval.classification_report()
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.99      1.00      0.99        99
#   meningioma       0.99      0.99      0.99       100
#      notumor       1.00      0.99      1.00       101
#    pituitary       1.00      1.00      1.00       100
#
#     accuracy                           0.99       400
#    macro avg       0.99      1.00      0.99       400
# weighted avg       1.00      0.99      1.00       400
